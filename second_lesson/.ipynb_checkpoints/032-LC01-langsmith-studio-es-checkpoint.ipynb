# %% [markdown]
# # Desarrollo de Agentes con LangChain 1.0: LangSmith Studio (ahora llamado Agent Builder)
# * LangSmith Studio es una interfaz visual gratuita para desarrollar y probar tus agentes de LangChain desde tu máquina local.
# * Para aprender más sobre cómo utilizarlo, consulta la [documentación](https://docs.langchain.com/oss/python/langchain/studio).
