# %% [markdown]
# # LangChain 1.0 Agent Post-Deployment: Observability with LangSmith
# * LangChain agents automatically support tracing through LangSmith for capturing, debugging, evaluating, and monitoring behavior.
# * Traces record every step of the agent’s execution, from the initial user input to the final response, including all tool calls, model interactions, and decision points.
# * This execution data helps you debug issues, evaluate performance across different inputs, and monitor usage patterns in production.
# * In order to do that, you will need :
#     * A LangSmith account (free to sign up).
#     * A LangSmith API key.
# * To learn more about how to use LangSmith, see the [documentation](https://docs.langchain.com/oss/python/langchain/observability).
