# %% [markdown]
# # LangChain 1.0 Agent Development: LangSmith Studio (Now called Agent Builder)
# * LangSmith Studio is a free visual interface for developing and testing your LangChain agents from your local machine (now called Agent Builder).
# * To learn more about how to use it, see the [documentation](https://docs.langchain.com/oss/python/langchain/studio).
