# %% [markdown]
# # LangChain 1.0 Agent Development: Agent Chat UI
# * Agent Chat UI is a Next.js application that provides a conversational interface for interacting with any LangChain agent.
# * It supports
#     * real-time chat,
#     * tool visualization,
#     * and advanced features like time-travel debugging
#     * and state forking.
# * Agent Chat UI works seamlessly with agents created using create_agent and provides interactive experiences for your agents with minimal setup, whether you’re running locally or in a deployed context (such as LangSmith).
# * To learn more about how to use the Agent Chat UI, check our detailed lesson in the LangChain 1.0 Quickstart block.
